# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ### Variables:
#
# For logfile

# %%
# import data in pandas dataframe (change the file name to your local file)
data = pd.read_csv('log6.csv', header = None)

# %%
print(data)
# Out:
#         0         1         2         3     4    5
# 0     0.0  0.497822  0.497041  0.025646  26.0  0.0
# 1     0.0  0.497814  0.497036  0.025670  26.0  0.0
# 2     0.0  0.497812  0.497028  0.025695  26.0  0.0
# 3     0.0  0.497810  0.497022  0.025720  26.0  0.0
# 4     0.0  0.497804  0.497019  0.025744  26.0  0.0
# ...   ...       ...       ...       ...   ...  ...
# 9995  0.0  0.000000  0.000000  0.000000   0.0  0.0
# 9996  0.0  0.000000  0.000000  0.000000   0.0  0.0
# 9997  0.0  0.000000  0.000000  0.000000   0.0  0.0
# 9998  0.0  0.000000  0.000000  0.000000   0.0  0.0
# 9999  0.0  0.000000  0.000000  0.000000   0.0  0.0
#
# [10000 rows x 6 columns]

# %%
# remove all-zeros rows
data = data[(data.T != 0).any()]

# %%
print(data)
# Out:
#            0         1         2         3     4    5
# 0        0.0  0.497822  0.497041  0.025646  26.0  0.0
# 1        0.0  0.497814  0.497036  0.025670  26.0  0.0
# 2        0.0  0.497812  0.497028  0.025695  26.0  0.0
# 3        0.0  0.497810  0.497022  0.025720  26.0  0.0
# 4        0.0  0.497804  0.497019  0.025744  26.0  0.0
# ..       ...       ...       ...       ...   ...  ...
# 845  16384.0 -0.017018  0.077930  0.070085   3.0  0.0
# 846  16384.0  0.002479  0.081758  0.158435   3.0  0.0
# 847  16384.0  0.005573  0.077317  0.168866   3.0  0.0
# 848  16384.0  0.012467  0.075083  0.176388   3.0  0.0
# 849  16384.0  0.013284  0.068096  0.189537   3.0  0.0
#
# [850 rows x 6 columns]

# %%
# plot all timeseries


for i in data:
    plt.figure()
    data[i].plot()

# %%
# Out:
# 65509.0
