# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# import data in pandas dataframe (change the file name to your local file)
data = pd.read_csv('logs/log1.csv', header = None)

# %%
print(data)
# Out:
#              0         1         2    3
# 0     0.128587  0.537941  0.025321  0.0
# 1     0.128809  0.539091  0.025265  0.0
# 2     0.126495  0.539234  0.025869  0.0
# 3     0.127027  0.539594  0.026331  0.0
# 4     0.126749  0.541555  0.025424  0.0
# ...        ...       ...       ...  ...
# 1307  0.000000  0.000000  0.000000  0.0
# 1308  0.000000  0.000000  0.000000  0.0
# 1309  0.000000  0.000000  0.000000  0.0
# 1310  0.000000  0.000000  0.000000  0.0
# 1311  0.000000  0.000000  0.000000  0.0
#
# [1312 rows x 4 columns]

# %%
# remove all-zeros rows
data = data[(data.T != 0).any()]

# %%
print(data)
# Out:
#             0         1         2    3
# 0    0.128587  0.537941  0.025321  0.0
# 1    0.128809  0.539091  0.025265  0.0
# 2    0.126495  0.539234  0.025869  0.0
# 3    0.127027  0.539594  0.026331  0.0
# 4    0.126749  0.541555  0.025424  0.0
# ..        ...       ...       ...  ...
# 493  0.136665  0.520762  0.024745  0.0
# 494  0.135003  0.519544  0.025041  0.0
# 495  0.135606  0.517799  0.025134  0.0
# 496  0.137612  0.516789  0.024718  0.0
# 497  0.136836  0.516990  0.023810  0.0
#
# [498 rows x 4 columns]

# %%
# plot all timeseries
for i in data:
    plt.figure()
    data[i].plot()

# %%
max(data[3])
# Out:
# 0.0
